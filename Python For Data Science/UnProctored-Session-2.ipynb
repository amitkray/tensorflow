# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix
pd.options.display.float_format = '{:.2f}'.format
data_crops=pd.read_csv('apy.csv')

crops = data_crops.copy()

naval = crops.isnull().sum()
crops2 = crops.dropna(axis=0) # created a new dataframe data2

# %%
crops2.columns
# Out:
# Index(['State_Name', 'District_Name', 'Crop_Year', 'Season', 'Crop', 'Area',
#        'Production'],
#       dtype='object')

# %%
production = crops2.groupby(['Season'])['Production'].agg('sum').sort_values()
production
# Out:
# Season
# Autumn            64413768.22
# Summer           170657925.03
# Winter           434549828.17
# Rabi            2051687553.08
# Kharif          4029970242.70
# Whole Year    134424837450.19
# Name: Production, dtype: float64

# %%
pd.set_option('display.max_rows', None)
crops_season = pd.crosstab(index=crops['Crop'],columns=crops2['Season'])
crops_season
# Out:
# Season                     Autumn       Kharif       Rabi         Summer       \
# Crop
# Apple                                0            0            0            0
# Arcanut (Processed)                  0            0            0            0
# Arecanut                             0           16          118            0
# Arhar/Tur                           18         6701          444           28
# Ash Gourd                            0            0            0            0
# Atcanut (Raw)                        0            0            0            0
# Bajra                                0         4630          262          331
# Banana                               6          131           60          190
# Barley                               0          134         3934            0
# Bean                                 0           20            0            0
# Beans & Mutter(Vegetable)            0            0            0            0
# ...

# %%
#high_prod_tamilnadu = crops2.groupby(['Crop_Year'],['State_Name'])['Production'].agg('sum').sort_values()
Cropdata = crops2[crops2['State_Name']=='Uttar Pradesh']
Result = Cropdata.groupby('Crop_Year') ['Production'].sum().sort_values()
print(Result)
# Out:
# Crop_Year
# 2000   157907591.50
# 1998   158892871.00
# 1999   162992482.00
# 2008   168238722.00
# 2002   170060872.00
# 2004   171209682.00
# 2001   172562165.20
# 2003   172597287.00
# 2005   175419236.00
# 2009   175526148.00
# 2007   179403646.00
# 2010   182882131.00
# 2006   187500450.00
# 1997   192027165.00
# 2011   195007190.00
# 2014   199418844.00
# 2012   205230988.00
# 2013   207615192.00
# Name: Production, dtype: float64

# %%
#high_prod_state = crops2.groupby(['State_Name']).agg({'Production': 'sum'})

high_prod_area = crops2.groupby(['Crop_Year'])['Area'].agg('sum').sort_values()
high_prod_area
# Out:
# Crop_Year
# 2015     4600298.00
# 2014   115743065.29
# 2013   141501896.29
# 2012   151698291.00
# 2007   152688604.30
# 2011   153609321.14
# 2002   157328631.21
# 1999   158612474.00
# 2005   162920317.65
# 2000   165289840.00
# 2001   165292712.67
# 2009   165608993.00
# 1998   166631554.00
# 2004   167756609.73
# 2003   169765517.54
# 2006   170588792.65
# 2008   170952985.00
# 2010   176601791.78
# 1997   231715046.00
# Name: Area, dtype: float64

# %%
lowest_crop_prod = crops2.groupby(['State_Name'])['Production'].agg('sum').sort_values()
lowest_crop_prod
# Out:
# State_Name
# Chandigarh                          63956.50
# Mizoram                           1661539.83
# Dadra and Nagar Haveli            1847871.00
# Sikkim                            2435735.00
# Manipur                           5230917.00
# Arunachal Pradesh                 6823912.60
# Jharkhand                        10777741.75
# Meghalaya                        12112496.00
# Tripura                          12522917.00
# Nagaland                         12765950.00
# Jammu and Kashmir                13291015.70
# Himachal Pradesh                 17805168.60
# Chhattisgarh                    100951908.01
# Uttarakhand                     132177355.00
# Odisha                          160904070.10
# Rajasthan                       281320270.50
# Telangana                       335147930.00
# Bihar                           366483596.66
# Haryana                         381273890.00
# Puducherry                      384724502.00
# Madhya Pradesh                  448840738.66
# ...

# %%
Cropdata = crops2[crops2['Crop_Year']==2015]
Result = Cropdata.groupby('Crop') ['Production'].sum().sort_values()
print(Result)
# Out:
# Crop
# Barley                    472.00
# Wheat                     840.40
# Jute                     2616.90
# Other Kharif pulses      2698.00
# Small millets            2911.00
# Soyabean                 3190.00
# Sesamum                  4139.60
# Rapeseed &Mustard        4616.60
# Horse-gram               9442.70
# Urad                    27063.10
# Ragi                    28326.00
# Groundnut               56161.20
# Potato                  57233.60
# Moong(Green Gram)       85222.50
# Maize                  179286.90
# Sugarcane              577157.20
# Rice                  5893687.00
# Name: Production, dtype: float64

# %%
std_area = crops2['Area'].std()
std_area
# Out:
# 50857.44002417676

# %%
Cropdata = crops2[crops2['State_Name']=='Madhya Pradesh']
highest_madhya = Cropdata.groupby('Crop') ['Production'].sum().sort_values()
print(highest_madhya)
# Out:
# Crop
# Orange                              0.00
# Other Vegetables                    0.00
# Mango                               0.00
# Other Fresh Fruits                  0.00
# Other Citrus Fruit                  0.00
# Citrus Fruit                        0.00
# Cauliflower                         0.00
# Grapes                              0.00
# Pome Fruit                          0.00
# Cabbage                             0.00
# Bhindi                              0.00
# Beans & Mutter(Vegetable)           0.00
# Tomato                              0.00
# Water Melon                         0.00
# Cashewnut                           0.00
# other misc. pulses                  0.21
# Brinjal                            19.00
# Tobacco                           814.02
# Safflower                        1593.48
# Cowpea(Lobia)                    2110.00
# Ragi                             2371.80
# Jute                             8650.00
# Castor seed                     12421.22
# ...

# %%
highest_area_prod = crops2.groupby(['State_Name'])['Area'].agg('sum').sort_values()
highest_area_prod
# Out:
# State_Name
# Chandigarh                        12502.00
# Andaman and Nicobar Islands      337083.40
# Dadra and Nagar Haveli           396515.00
# Puducherry                       548736.00
# Mizoram                          993640.17
# Goa                             1205678.50
# Sikkim                          1524479.00
# Manipur                         2007254.00
# Meghalaya                       4035028.00
# Arunachal Pradesh               4364340.00
# Tripura                         4641609.00
# Nagaland                        6053234.00
# Jammu and Kashmir               9264621.00
# Jharkhand                       9391046.23
# Himachal Pradesh               10003417.00
# Uttarakhand                    18792007.00
# Kerala                         31802252.08
# Assam                          70378752.00
# Telangana                      81310646.00
# Chhattisgarh                   82931353.00
# Haryana                        89514473.00
# ...

# %%
mean_area_prod = crops2['Area'].mean()
mean_area_prod
# Out:
# 12167.414481909218

# %%
highest_prod_crop = crops2.groupby('Crop') ['Production'].sum().sort_values()
highest_prod_crop
# Out:
# Crop
# Apple                                  0.00
# Pear                                   0.00
# Other Dry Fruit                        0.00
# Other Citrus Fruit                     0.00
# Peas  (vegetable)                      0.00
# Plums                                  0.00
# Pump Kin                               0.00
# Litchi                                 0.00
# Lab-Lab                                0.00
# Ribed Guard                            0.00
# Cucumber                               0.00
# Snak Guard                             0.00
# Peach                                  0.00
# Beet Root                              0.00
# other fibres                           0.00
# Ber                                    0.00
# Yam                                    0.00
# Ash Gourd                              0.00
# Water Melon                            0.00
# Bitter Gourd                         353.00
# Turnip                               363.00
# ...

# %%
crops2.head()
# Out:
#                     State_Name District_Name  Crop_Year       Season  \
# 0  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
#
#                   Crop    Area  Production
# 0             Arecanut 1254.00     2000.00
# 1  Other Kharif pulses    2.00        1.00
# 2                 Rice  102.00      321.00
# 3               Banana  176.00      641.00
# 4            Cashewnut  720.00      165.00

# %%
Cropdata = crops2[crops2['Season']=='Summer     ']
highest_wint = Cropdata.groupby('Crop') ['Production'].sum().sort_values(ascending=False)
print(highest_wint)
# Out:
# Crop
# Rice                    127702773.53
# Maize                    13924212.20
# Bajra                     7436768.00
# Groundnut                 6827896.60
# Paddy                     5110559.00
# Moong(Green Gram)         2433090.00
# Onion                     2156529.00
# Sesamum                   1840644.80
# Sunflower                  671968.00
# Banana                     613260.00
# Potato                     586412.00
# Urad                       444334.80
# Ragi                       297260.30
# Jowar                      236454.00
# Dry chillies               178807.00
# Wheat                       52693.20
# Peas & beans (Pulses)       41398.00
# Total foodgrain             39126.00
# Cotton(lint)                17190.00
# Arhar/Tur                   16414.00
# Tobacco                     13274.00
# Cowpea(Lobia)                8289.00
# Sugarcane                    4900.00
# Brinjal                      1515.00
# Dry ginger                    930.00
# ...
