# %%
import numpy as np
import pandas as pd

# %%
hotel_data = pd.read_csv("hotel.csv")

# %%
hotel_data['is_canceled'] = hotel_data['is_canceled'].astype("category")

# %%
hotel_data['is_canceled'].nbytes
# Out:
# 40076

# %%
hotel_data
# Out:
#               hotel is_canceled  arrival_date_year arrival_date_month  \
# 0      Resort Hotel         0.0               2015               July
# 1      Resort Hotel         0.0               2015               July
# 2      Resort Hotel         0.0               2015               July
# 3      Resort Hotel         0.0               2015               July
# 4      Resort Hotel         0.0               2015               July
# ...             ...         ...                ...                ...
# 40055    City Hotel         0.0               2015             August
# 40056    City Hotel         0.0               2015             August
# 40057    City Hotel         0.0               2015             August
# 40058    City Hotel         0.0               2015             August
# 40059    City Hotel         0.0               2015             August
#
#        arrival_date_day_of_month  stays_in_weekend_nights  \
# 0                              1                        0
# ...

# %%
hotel_data['arrival_date_month'] = hotel_data['arrival_date_month'].astype("category")

# %%
hotel_data['customer_type'] = hotel_data['customer_type'].astype("category")

# %%
hotel_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40060 entries, 0 to 40059
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   hotel                      40060 non-null  object
#  1   is_canceled                40060 non-null  category
#  2   arrival_date_year          40060 non-null  int64
#  3   arrival_date_month         40060 non-null  category
#  4   arrival_date_day_of_month  40060 non-null  int64
#  5   stays_in_weekend_nights    40060 non-null  int64
#  6   stays_in_week_nights       40060 non-null  int64
#  7   adults                     40060 non-null  int64
#  8   children                   40060 non-null  int64
#  9   country                    39596 non-null  object
#  10  market_segment             40060 non-null  object
#  11  is_repeated_guest          40060 non-null  int64
#  12  reserved_room_type         40060 non-null  object
# ...

# %%
df = pd.read_csv("test3.csv")

# %%
df.dropna(how='any', inplace=True)

# %%
df
# Out:
# Empty DataFrame
# Columns: [2, 3.2, 1.2, NaN]
# Index: []

# %%
age=20
if age < 18:
    print("Inek")
else:
    print("ghh")
# Out:
# ghh
